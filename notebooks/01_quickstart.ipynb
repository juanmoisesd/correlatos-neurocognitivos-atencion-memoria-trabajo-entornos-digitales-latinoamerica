# %% [markdown]
# # Quickstart: Neurocognitive Data Analysis
#
# This notebook provides a quick overview of how to load and explore the dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load example data (once available)
# df = pd.read_csv('../data/clean/dataset.csv')
# df.head()
